# %% [markdown]
# <a href="https://colab.research.google.com/github/gillopy/Ande_Demanda_de_Potencia_Mensual/blob/main/Ande_Multiple_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

 # Datos proporcionados
data = {
  'Año': [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
  'Enero': [2077.0, 2403.7, 2474.0, 2656.0, 2785.0, 2950.0, 2977.0, 3451.0, 3539.0, 3504.0, 4206.0, 4200.0, 4723.0],
  'Febrero': [2170.0, 2425.4, 2536.9, 2643.0, 2917.0, 3026.0, 3037.0, 3481.6, 3469.0, 3777.0, 3948.0, 4072.0, 4905.0],
  'Marzo': [2196.3, 2272.0, 2233.4, 2583.0, 2701.0, 3095.0, 3066.0, 3053.6, 3563.0, 3487.0, 3867.0, 3956.0, 5027.0],
  'Abril': [1926.6, 2096.0, 2433.1, 2186.0, 2887.0, 2371.0, 2831.0, 2761.0, 3050.0, 3067.0, 3286.0, 3443.0, 4497.0],
  'Mayo': [1896.0, 2116.0, 2023.3, 2007.0, 1970.0, 2343.0, 2744.0, 2517.0, 2480.0, 2830.0, 2590.0, 2938.0, 3940.0],
  'Junio': [1842.0, 1893.0, 1958.0, 2186.0, 2058.0, 2131.0, 2283.0, 2432.0, 2587.0, 2649.0, 2576.0, 2805.0, 3330.0],
  'Julio': [1830.0, 1994.0, 2004.0, 2089.0, 2175.0, 2204.0, 2432.0, 2306.0, 2540.0, 2547.0, 2815.0, 2990.0, 3438.0],
  'Agosto': [1921.0, 1981.7, 2076.0, 2264.0, 2290.0, 2478.0, 2544.0, 2538.0, 2674.0, 2857.0, 2871.0, 3430.0, 3378.0],
  'Septiembre': [2150.0, 2120.0, 2188.0, 2603.0, 2287.0, 2508.0, 2662.0, 2874.0, 3261.0, 3437.0, 2878.0, 4236.0, 4126.0],
  'Octubre': [2191.2, 2210.0, 2619.0, 2584.0, 2713.0, 2951.0, 2887.0, 3553.0, 3410.0, 3400.0, 3130.0, 4204.0, 4587.0],
  'Noviembre': [2276.5, 2231.0, 2338.0, 2645.0, 2779.0, 2658.0, 3161.0, 3428.0, 3560.0, 3485.0, 3488.0, 4372.0, 4714.0],
  'Diciembre': [2383.6, 2390.0, 2563.0, 2619.0, 2876.0, 3135.0, 3226.0, 3407.0, 3401.0, 3760.0, 4270.0, 4745.0, 4553.0]
 }

df = pd.DataFrame(data)

 # Convertir el DataFrame a formato largo (tidy data)
df_long = pd.melt(df, id_vars=['Año'], var_name='Mes', value_name='Valor')

 # Crear el gráfico de series de tiempo múltiples con relplot
plt.figure(figsize= (12, 6))
sns.relplot(data=df_long, x='Año', y='Valor', hue='Mes', kind='line', marker='o')
plt.title('Evolución de los valores a lo largo del tiempo')
plt.xlabel('Año')
plt.ylabel('Valor')
plt.xticks(rotation=45) # Rotar las etiquetas del eje x para mayor legibilidad
plt.tight_layout() # Ajustar el diseño para evitar que las etiquetas se superpongan
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
  'Año': [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
  'Enero': [2077.0, 2403.7, 2474.0, 2656.0, 2785.0, 2950.0, 2977.0, 3451.0, 3539.0, 3504.0, 4206.0, 4200.0, 4723.0],
  'Febrero': [2170.0, 2425.4, 2536.9, 2643.0, 2917.0, 3026.0, 3037.0, 3481.6, 3469.0, 3777.0, 3948.0, 4072.0, 4905.0],
  'Marzo': [2196.3, 2272.0, 2233.4, 2583.0, 2701.0, 3095.0, 3066.0, 3053.6, 3563.0, 3487.0, 3867.0, 3956.0, 5027.0],
  'Abril': [1926.6, 2096.0, 2433.1, 2186.0, 2887.0, 2371.0, 2831.0, 2761.0, 3050.0, 3067.0, 3286.0, 3443.0, 4497.0],
  'Mayo': [1896.0, 2116.0, 2023.3, 2007.0, 1970.0, 2343.0, 2744.0, 2517.0, 2480.0, 2830.0, 2590.0, 2938.0, 3940.0],
  'Junio': [1842.0, 1893.0, 1958.0, 2186.0, 2058.0, 2131.0, 2283.0, 2432.0, 2587.0, 2649.0, 2576.0, 2805.0, 3330.0],
  'Julio': [1830.0, 1994.0, 2004.0, 2089.0, 2175.0, 2204.0, 2432.0, 2306.0, 2540.0, 2547.0, 2815.0, 2990.0, 3438.0],
  'Agosto': [1921.0, 1981.7, 2076.0, 2264.0, 2290.0, 2478.0, 2544.0, 2538.0, 2674.0, 2857.0, 2871.0, 3430.0, 3378.0],
  'Septiembre': [2150.0, 2120.0, 2188.0, 2603.0, 2287.0, 2508.0, 2662.0, 2874.0, 3261.0, 3437.0, 2878.0, 4236.0, 4126.0],
  'Octubre': [2191.2, 2210.0, 2619.0, 2584.0, 2713.0, 2951.0, 2887.0, 3553.0, 3410.0, 3400.0, 3130.0, 4204.0, 4587.0],
  'Noviembre': [2276.5, 2231.0, 2338.0, 2645.0, 2779.0, 2658.0, 3161.0, 3428.0, 3560.0, 3485.0, 3488.0, 4372.0, 4714.0],
  'Diciembre': [2383.6, 2390.0, 2563.0, 2619.0, 2876.0, 3135.0, 3226.0, 3407.0, 3401.0, 3760.0, 4270.0, 4745.0, 4553.0]
 }

df = pd.DataFrame(data)

# Convertir a formato largo (tidy data)
df_long = pd.melt(df, id_vars=['Año'], var_name='Mes', value_name='Valor')
df_long['Mes'] = pd.Categorical(df_long['Mes'], categories=['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'], ordered=True) # Ordenar meses

# Crear el gráfico con facetas (relplot)
sns.set_theme(style="whitegrid")  # Estilo más limpio
g = sns.relplot(
    data=df_long, x="Mes", y="Valor", col="Año", hue="Año",
    kind="line", palette="viridis", linewidth=2, zorder=5,  # Paleta de colores más profesional
    col_wrap=4, height=3, aspect=1.2,  # Ajustar tamaño y número de columnas
    legend=False,  # La leyenda se maneja aparte
    facet_kws={'sharey': False} # Escala y diferente en cada facet
)

# Personalizar cada subplot
for year, ax in g.axes_dict.items():
    ax.set_title(year, fontsize=12, fontweight="bold")  # Título del facet

    # Líneas grises de fondo (opcional, para contexto)
    sns.lineplot(
        data=df_long, x="Mes", y="Valor", units="Año", estimator=None,
        color=".8", linewidth=0.8, ax=ax, zorder=0  # Líneas más delgadas y detrás
    )
    ax.tick_params(axis='x', labelsize=10, rotation=45) # Rotar etiquetas del eje x
    ax.tick_params(axis='y', labelsize=10)
    ax.set_xlabel("") # Eliminar etiquetas de los ejes de cada facet
    ax.set_ylabel("")

# Mejorar el diseño general
g.set_titles("")  # Eliminar títulos automáticos de los facets
g.set_axis_labels("Mes", "Valor")  # Etiquetas de los ejes principales
g.fig.suptitle('Evolución Mensual de Valores por Año', fontsize=14, fontweight="bold", y=1.02)  # Título principal más grande
g.tight_layout(w_pad=1) # Ajustar espaciado
plt.subplots_adjust(top=0.92) # Ajustar espacio superior para el título

# Crear la leyenda manualmente (fuera de los facets)
handles = [plt.Line2D([], [], color=palette[i], linewidth=2) for i, palette in enumerate(g._legend_data.values())]
labels = list(g._legend_data.keys())
g.fig.legend(handles, labels, loc='upper center', ncol=7, fontsize=10, bbox_to_anchor=(0.5, 0.96), frameon=False) # Leyenda en la parte superior


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
  'Año': [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
  'Enero': [2077.0, 2403.7, 2474.0, 2656.0, 2785.0, 2950.0, 2977.0, 3451.0, 3539.0, 3504.0, 4206.0, 4200.0, 4723.0],
  'Febrero': [2170.0, 2425.4, 2536.9, 2643.0, 2917.0, 3026.0, 3037.0, 3481.6, 3469.0, 3777.0, 3948.0, 4072.0, 4905.0],
  'Marzo': [2196.3, 2272.0, 2233.4, 2583.0, 2701.0, 3095.0, 3066.0, 3053.6, 3563.0, 3487.0, 3867.0, 3956.0, 5027.0],
  'Abril': [1926.6, 2096.0, 2433.1, 2186.0, 2887.0, 2371.0, 2831.0, 2761.0, 3050.0, 3067.0, 3286.0, 3443.0, 4497.0],
  'Mayo': [1896.0, 2116.0, 2023.3, 2007.0, 1970.0, 2343.0, 2744.0, 2517.0, 2480.0, 2830.0, 2590.0, 2938.0, 3940.0],
  'Junio': [1842.0, 1893.0, 1958.0, 2186.0, 2058.0, 2131.0, 2283.0, 2432.0, 2587.0, 2649.0, 2576.0, 2805.0, 3330.0],
  'Julio': [1830.0, 1994.0, 2004.0, 2089.0, 2175.0, 2204.0, 2432.0, 2306.0, 2540.0, 2547.0, 2815.0, 2990.0, 3438.0],
  'Agosto': [1921.0, 1981.7, 2076.0, 2264.0, 2290.0, 2478.0, 2544.0, 2538.0, 2674.0, 2857.0, 2871.0, 3430.0, 3378.0],
  'Septiembre': [2150.0, 2120.0, 2188.0, 2603.0, 2287.0, 2508.0, 2662.0, 2874.0, 3261.0, 3437.0, 2878.0, 4236.0, 4126.0],
  'Octubre': [2191.2, 2210.0, 2619.0, 2584.0, 2713.0, 2951.0, 2887.0, 3553.0, 3410.0, 3400.0, 3130.0, 4204.0, 4587.0],
  'Noviembre': [2276.5, 2231.0, 2338.0, 2645.0, 2779.0, 2658.0, 3161.0, 3428.0, 3560.0, 3485.0, 3488.0, 4372.0, 4714.0],
  'Diciembre': [2383.6, 2390.0, 2563.0, 2619.0, 2876.0, 3135.0, 3226.0, 3407.0, 3401.0, 3760.0, 4270.0, 4745.0, 4553.0]
 }

df = pd.DataFrame(data)


# Convertir a formato largo (tidy data)
df_long = pd.melt(df, id_vars=['Año'], var_name='Mes', value_name='Valor')
df_long['Mes'] = pd.Categorical(df_long['Mes'], categories=['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'], ordered=True) # Ordenar meses

#Establecer el estilo y tamaño de la figura
sns.set_theme(style="whitegrid")
plt.rcParams['figure.dpi'] = 150  # Resolución más alta
g = sns.relplot(
    data=df_long, x="Mes", y="Valor", col="Año", hue="Año",
    kind="line", palette="viridis", linewidth=2, zorder=5,
    col_wrap=3, height=4, aspect=1.5,  # Ajustar tamaño y número de columnas
    legend=False,
    facet_kws={'sharey': False}
)

# Personalizar cada subplot
for year, ax in g.axes_dict.items():
    ax.set_title(year, fontsize=14, fontweight="bold")

    # Recuadro para cada gráfico
    ax.patch.set_edgecolor('black')
    ax.patch.set_linewidth(1)

    # Líneas grises de fondo (opcional, para contexto)
    sns.lineplot(
        data=df_long, x="Mes", y="Valor", units="Año", estimator=None,
        color=".8", linewidth=1, ax=ax, zorder=0
    )

    # Líneas de rayas para valores específicos (ejemplo: promedio del año)
    promedio_anual = df_long[df_long['Año'] == int(year)]['Valor'].mean()
    ax.axhline(promedio_anual, color='gray', linestyle='--', linewidth=1, label='Promedio Anual')

    # Puntos en los valores más altos (ejemplo: máximo de cada mes)
    maximos_mes = df_long[df_long['Año'] == int(year)].groupby('Mes')['Valor'].max()
    for mes, max_val in maximos_mes.items():
        ax.plot(mes, max_val, 'o', color='red', markersize=8)

    ax.tick_params(axis='x', labelsize=12, rotation=45)
    ax.tick_params(axis='y', labelsize=12)
    ax.set_xlabel("")
    ax.set_ylabel("")

# Mejorar el diseño general
g.set_titles("")
g.set_axis_labels("Mes", "Valor")
g.fig.suptitle('Evolución Mensual de Valores por Año', fontsize=16, fontweight="bold", y=1.02)
g.tight_layout(w_pad=1)
plt.subplots_adjust(top=0.92)

# Crear la leyenda manualmente (fuera de los facets)
handles = [plt.Line2D([], [], color=palette[i], linewidth=2) for i, palette in enumerate(g._legend_data.values())]
labels = list(g._legend_data.keys())
g.fig.legend(handles, labels, loc='upper center', ncol=4, fontsize=12, bbox_to_anchor=(0.5, 0.98), frameon=False)

plt.show()
# Out:
# <ipython-input-7-b3e019e65ea5>:58: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   maximos_mes = df_long[df_long['Año'] == int(year)].groupby('Mes')['Valor'].max()
# <ipython-input-7-b3e019e65ea5>:58: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   maximos_mes = df_long[df_long['Año'] == int(year)].groupby('Mes')['Valor'].max()
# <ipython-input-7-b3e019e65ea5>:58: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ...
